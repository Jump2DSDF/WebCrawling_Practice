# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = "https://www.livesport.com/kr/team/manchester-united/ppjDR086/"
html = urlopen(url)
bs_obj01 = BeautifulSoup(html, "html.parser")
win01 = bs_obj01.find_all("span", {"class":"_simpleText_1loh2_4 _webTypeSimpleText01_1loh2_8"})
win01
# Out:
# []

# %%
bs_obj01
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <title>Livesport: 맨체스터 유나이티드 - 결과, 일정, 맨체스터 유나이티드 vs 트벤테 live</title>
# <script charset="UTF-8" data-document-language="true" data-domain-script="be4cd6ae-414e-4784-a9f8-29c9eb574714" defer="" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript"></script>
# <link crossorigin="" href="https://713.ds.lsapp.eu/pq_graphql" rel="preconnect"/>
# <link crossorigin="" href="https://500.flashscore.ninja" rel="preconnect"/>
# <link as="font" crossorigin="" href="https://static.flashscore.com/res/font/LivesportFinderLatin-Regular_Static.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://static.flashscore.com/res/font/LivesportFinderLatin-Bold_Static.woff2" rel="preload" type="font/woff2"/>
# <noscript>
# <meta content="0;url=https://m.flashscore.co.kr/" http-equiv="refresh">
# </meta></noscript>
# ...

# %%
# !pip install --upgrade selenium
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.7 MB 2.6 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/9.7 MB 9.6 MB/s eta 0:00:01
#    ------ --------------------------------- 1.6/9.7 MB 12.8 MB/s eta 0:00:01
#    -------------- ------------------------- 3.5/9.7 MB 20.2 MB/s eta 0:00:01
#    ------------------------- -------------- 6.3/9.7 MB 28.7 MB/s eta 0:00:01
#    ------------------------------------- -- 9.1/9.7 MB 34.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 34.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: selenium
#     Found existing installation: selenium 4.24.0
#     Uninstalling selenium-4.24.0:
#       Successfully uninstalled selenium-4.24.0
# ...

# %%
# from selenium import webdriver

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

import time

from bs4 import BeautifulSoup
import requests

# %%
chrome_options = webdriver.ChromeOptions()
service = Service("chromedriver.exe")
driver = webdriver.Chrome(service=service, options=chrome_options)
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In[15], line 3
#       1 chrome_options = webdriver.ChromeOptions()
#       2 service = Service("chromedriver.exe")
# ----> 3 driver = webdriver.Chrome(service=service, options=chrome_options)
#
# File ~\.conda\envs\py3_8_5\lib\site-packages\selenium\webdriver\chrome\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# ...

# %%
# driver = webdriver.Chrome('chromedriver.exe')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 driver = webdriver.Chrome('chromedriver.exe')
#
# File ~\.conda\envs\py3_8_5\lib\site-packages\selenium\webdriver\chrome\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# File ~\.conda\envs\py3_8_5\lib\site-packages\selenium\webdriver\chromium\webdriver.py:50, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      47 self.service = service
# ...

# %%
driver.implicity_wait(3)
driver.get("https://www.livesport.com/team/manchester-united/ppjDR086/")
